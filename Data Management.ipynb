# %%
# Import Functions
import Functions as fn

# %%
cfg_list = ('SPY','AAPL','MSFT','GOOGL','AMZN','USFD','SYY','NFLX','GME','AMC')
start_date = '2018-01-01'
end_date = '2025-12-31'
cfg_list = fn.tc.tuple_check(cfg_list)

# %% [markdown]
# Initial Loads

# %%
for ticker in cfg_list:
    cfg = fn.tc.MLConfig(ticker, start_date, end_date)
    fn.Step1.fMain(cfg) # Data

# %%
for ticker in cfg_list:
    cfg = fn.tc.MLConfig(ticker, start_date, end_date)
    fn.Step2.fMain(cfg) # Train

# %%
for ticker in cfg_list:
    cfg = fn.tc.MLConfig(ticker, start_date, end_date)
    fn.Step3.fMain(cfg) # Score

# %%
for ticker in cfg_list:
    cfg = fn.tc.MLConfig(ticker, start_date, end_date)
    fn.Step4.fMain(cfg) # Predict

# %% [markdown]
# Retrain Models

# %%
for ticker in cfg_list:
    cfg = fn.tc.MLConfig(ticker, start_date, end_date)
    fn.Step5.fMain(cfg) # Retrain with latest data

# %% [markdown]
# Backtesting

# %%
for ticker in cfg_list:
    cfg = fn.tc.MLConfig(ticker, start_date, end_date)
    fn.Step6.fMain(cfg) # Backtest ticker

# %%
fn.Step6.combine_backtest_files() # Combine backtest files into one

# %% [markdown]
# Walkforward

# %%
for ticker in cfg_list:
    cfg = fn.tc.MLConfig(ticker, start_date, end_date)
    fn.Step7.fMain(cfg) # Walkforward test with retraining every 3 months and backtesting every 3 months

# %%
fn.Step7.combine_walkforward_files() # Combine walkforward files into one
